# %% [markdown]
# ## Wikipedia list of metropolitan areas
#
# _Note: adapted from Introduction to Scientific Programming's exercises_
#
# We want to count how many of the top 50 metropolitan areas are currently chinese according to that list:
#
# https://en.wikipedia.org/wiki/List_of_metropolitan_areas_by_population

# %%
# !pip install requests
# !pip install pandas
# !pip install lxml
# Out:
# Requirement already satisfied: requests in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: pandas in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting lxml
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/31/58/e3b3dd6bb2ab7404f1f4992e2d0e6926ed40cef8ce1b3bbefd95877499e1/lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 991.0 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/3.8 MB 6.0 MB/s eta 0:00:01
#    -------------- ------------------------- 1.3/3.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.3/3.8 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 14.1 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.3

# %%
import requests

# %%
html = requests.get("https://en.wikipedia.org/wiki/List_of_metropolitan_areas_by_population")
html.ok
# Out:
# True

# %%
html.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of largest cities - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August",\n"September","October","November","December"],"wgRequestId":"69762e7d-c02e-4e94-b357-5677a0a4789e","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_largest_cities","wgTitle":"List of largest cities","wgCurRevisionId":1172714415,"wgRevisionId":1172714415,"wgArticleId":14649921,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Portuguese-language sources (pt)","CS1 Spanish-language sources (es)","CS1 uses Chinese-language script (zh)","CS1 Chinese-language sources (zh)","All articles with dead external links","Articles with dead external links from December 2017","Articles with permanently dead external links","Webarchive template wayback links","CS1 errors: missing periodical","Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely semi-protected pages","Use dmy dates from October 2020",\n"Pages using the Kartographer extension","Cities-related lists of superlatives","Largest things","Lists of cities (worldwide) by population","Urban geography"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_largest_cities","wgRelevantArticleId":14649921,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgRedirectedFrom":"List_of_metropolitan_areas_by_population","wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":70000,"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English",\n"wgInternalRedirectTargetUrl":"/wiki/List_of_largest_cities","wgCoordinates":{"lat":30.008333333333333,"lon":107.56666666666666},"wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q1496553","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile"," ...

# %%
html.headers
# Out:
# {'date': 'Mon, 11 Sep 2023 18:30:46 GMT', 'server': 'mw1414.eqiad.wmnet', 'x-content-type-options': 'nosniff', 'content-language': 'en', 'accept-ch': '', 'vary': 'Accept-Encoding,Cookie', 'last-modified': 'Mon, 11 Sep 2023 08:57:28 GMT', 'content-type': 'text/html; charset=UTF-8', 'content-encoding': 'gzip', 'age': '72957', 'x-cache': 'cp3072 miss, cp3072 hit/4', 'x-cache-status': 'hit-front', 'server-timing': 'cache;desc="hit-front", host;desc="cp3072"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=12-Sep-2023;Path=/;HttpOnly;secure;Expires=Sat, 14 Oct 2023 12:00:00 GMT, WMF-Last-Access-Global=12-Sep-2023;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Sat, 14 Oct 2023 12:00:00 GMT, WMF-DP=f5a;Path=/;HttpOnly;secure;Expires=Wed, 13 Sep 2023 00:00:00 GMT, GeoIP=DE:BW:Mannheim:49.50:8.49:v4; Path=/; secure; Domain=.wikipedia.org, NetworkProbeLimit=0.001;Path=/;Secure;Max-Age=3600', 'x-client-ip': '134.155.205.45', 'cache-control': 'private, s-maxage=0, max-age=0, must-revalidate', 'accept-ranges': 'bytes', 'content-length': '56936'}

# %%
import pandas as pd

html_dataframe_object = pd.read_html(html.content, header = 0)

# %%
type(html_dataframe_object)
# Out:
# list

# %%
html_dataframe_object[0]
# Out:
#                                             Ekistics
# 0  List of largest cities List of cities proper b...
# 1                                      Cities portal
# 2                                                vte

# %%
len(html_dataframe_object)
# Out:
# 4

# %%
df = html_dataframe_object[1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City[a]                          82 non-null     object
#  1   Country                          82 non-null     object
#  2   UN 2018 population estimates[b]  82 non-null     object
#  3   City proper[c]                   82 non-null     object
#  4   City proper[c].1                 82 non-null     object
#  5   City proper[c].2                 82 non-null     object
#  6   City proper[c].3                 82 non-null     object
#  7   Urban area[8]                    82 non-null     object
#  8   Urban area[8].1                  82 non-null     object
#  9   Urban area[8].2                  82 non-null     object
#  10  Metropolitan area[d]             82 non-null     object
#  11  Metropolitan area[d].1           82 non-null     object
#  12  Metropolitan area[d].2           82 non-null     object
# dtypes: object(13)
# memory usage: 8.6+ KB

# %%
df.head()
# Out:
#     City[a]  Country  UN 2018 population estimates[b]         City proper[c]  \
# 0   City[a]  Country  UN 2018 population estimates[b]             Definition
# 1       NaN      NaN                              NaN                    NaN
# 2     Tokyo    Japan                         37468000  Metropolis prefecture
# 3     Delhi    India                         28514000  Municipal corporation
# 4  Shanghai    China                         25582000           Municipality
#
#   City proper[c].1 City proper[c].2 City proper[c].3 Urban area[8]  \
# 0       Population       Area (km2)   Density (/km2)    Population
# 1              NaN              NaN              NaN           NaN
# 2         13515271             2191       6,169 [13]      37732000
# 3         16753235             1484      11,289 [15]      32226000
# 4         24870895             6341   3,922 [17][18]      24073000
#
#   Urban area[8].1 Urban area[8].2 Metropolitan area[d] Metropolitan area[d].1  \
# 0      Area (km2)  Density (/km2)           Population             Area (km2)
# 1             NaN             NaN                  NaN                    NaN
# 2            8231       4,584 [e]             37274000                  13452
# 3            2344      13,748 [f]             29000000                   3483
# 4            4333       5,556 [g]                    —                      —
#
#   Metropolitan area[d].2
# 0         Density (/km2)
# 1                    NaN
# 2             2,771 [14]
# 3             8,326 [16]
# 4                      —

# %%
df = df.drop(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 1 to 82
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City[a]                          81 non-null     object
#  1   Country                          81 non-null     object
#  2   UN 2018 population estimates[b]  81 non-null     object
#  3   City proper[c]                   81 non-null     object
#  4   City proper[c].1                 81 non-null     object
#  5   City proper[c].2                 81 non-null     object
#  6   City proper[c].3                 81 non-null     object
#  7   Urban area[8]                    81 non-null     object
#  8   Urban area[8].1                  81 non-null     object
#  9   Urban area[8].2                  81 non-null     object
#  10  Metropolitan area[d]             81 non-null     object
#  11  Metropolitan area[d].1           81 non-null     object
#  12  Metropolitan area[d].2           81 non-null     object
# dtypes: object(13)
# memory usage: 9.0+ KB

# %%
df.head()
# Out:
#      City[a] Country UN 2018 population estimates[b]         City proper[c]  \
# 1        NaN     NaN                             NaN                    NaN
# 2      Tokyo   Japan                        37468000  Metropolis prefecture
# 3      Delhi   India                        28514000           Capital City
# 4   Shanghai   China                        25582000           Municipality
# 5  São Paulo  Brazil                        21650000           Municipality
#
#   City proper[c].1 City proper[c].2 City proper[c].3 Urban area[8]  \
# 1              NaN              NaN              NaN           NaN
# 2         13515271             2191        6,169[13]      39105000
# 3         16753235             1484       11,289[15]      31870000
# 4         24870895             6341    3,922[17][18]      22118000
# 5         12252023             1521        8,055[19]      22495000
#
#   Urban area[8].1 Urban area[8].2 Metropolitan area[d] Metropolitan area[d].1  \
# 1             NaN             NaN                  NaN                    NaN
# 2            8231        4,751[e]             37274000                  13452
# 3            2233       14,272[f]             29000000                   3483
# 4            4069        5,436[g]                    —                      —
# 5            3237        6,949[h]             21734682                   7947
#
#   Metropolitan area[d].2
# 1                    NaN
# 2              2,771[14]
# 3              8,326[16]
# 4                      —
# 5              2,735[20]

# %%
print(len(df[df.Country == "China"]), 'out of', len(df))
# Out:
# 20 out of 82
