# %% [markdown]
# ## Wrap Up: Etherscan

# %%
url = "https://etherscan.io/"

# %% [markdown]
# Simple GET request without JS.

# %%
import requests

html = requests.get(url)

html.content
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"></head><body class="no-js"><div class="main-wrapper" role="main"><div class="main-content"><noscript><div id="challenge-error-title"><div class="h2"><span class="icon-wrapper"><div class="heading-icon warning-icon"></div></span><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></div></noscript></div></div><script>(function(){window._cf_chl_opt={cvId: \'2\',cZone: "etherscan.io",cType: \'interactive\',cNounce: \'77492\',cRay: \'8091af71fab02c10\',cHash: \'79898d4d9748f8a\',cUPMDTk: "\\/?__cf_chl_tk=3.X6G5MnGeD5kQX1loxxp0D6L_uHrvFrhComxccAGs8-1695125005-0-gaNycGzNCXs",cFPWv: \'b\',cTTimeMs: \'1000\',cMTimeMs: \'0\',cTplV: 5,cTplB: \'cf\',cK: "visitor-time",fa: "\\/?__cf_chl_f_tk=3.X6G5MnGeD5kQX1loxxp0D6L_uHrvFrhComxccAGs8-1695125005-0-gaNycGzNCXs",md: "Shtm9w56lkG6OIgsdz_515j0.g_gtVvDylXQcG8_ERM-1695125005-0-ASY7zphmOtqos-slTIfXhq9585T6g8s4gvR4ENyk0R9VhesZapSEY95gYgGWCg-FUaJ2f013JpE0JjpXvOfmjVOEKQyVnKT6WlybV0IGuE7CjKL6LhcZKSmP7jsQI5R67Vx8b5KC3oOLe3roZ6q_R-ed71wIf9qxoTTFXjOfcz7h4ghb92kJUSLnpBQmkphpo11WHaK6za2ubYfkXwMwSy7ZiXp1yyEdGOTcqYOUGIKqPafhvWM7cswmokrq0s-8FbHg5fyuPRVJFU-QvmTw-Shs11wc-IHSsIWTNcxs9udO1ob14qi8ecfme_zUsxX_qTPRF6EfQswoZQR_BXjvnrJm1uesjhXBAKJcr2Bvh3iA3LqtDMax_ucmt6tm4VU0aBoLCKJkoCFt_Y9Uh8ZbRVStXmZRsSo3iZPqmUYQMvLuzHLM8ppb3pKM6frcbZpi1OarXv_WGJWK3Sp66iZ2AoS3nKBjGOLSezs3BqslIAo9AMSzS7Bgqyg6s9Xh6OWnuIUfH8sGuUovrZawgNZ48lJdBMXuREuFe2eK6ttDDZiud6QigdwyOyTai4HVUhdA9P-Qd-V49rgdAIDuf4Pw5ng7SHxs5c3v9YCdd32jXuRlsuCRigJRs-W1orl-PhUHTuthCiAce0LKOH2Z_lMivVv39qMffzCR3OODcmWnRBTQSELusAADbKym86vVLdyvyBXJmHiygsO2rDU0gJIjugG5hz-rCmrGL3X6GpHHE7un3caDfeVQU_Qm3rWkwvWMfI1TiF3nPZe-17y9VIsU_FvnGCerYigmlOeeAw6cp_42YCC7oENB
RzLzIuMzEuMA==\',rm: \'R0VU\',d: \'...\',t: \'MTY5NTEyNTAwNS4xMTkwMDA=\',cT: Math.floor(Date.now() / 1000),m: \'QuX6ZEEcaDae0SGnm3qGWgKNk2OvvUGTkp1udjwUCBc=\',i1: \'QjFdxEsA828MJKzmTX/ySw==\',i2: \'Tkv7FhFSz/aqjspSuKh2cQ==\',zh: \'qb4aFuGlbJn/rUOkKXjUqElKDKE10jDqu5PE014OTwk=\',uh: \'YE9XOpG5TeHmhA1zfs5mxC8CrRZzq2a/+r+OU7dliYQ=\',hh: \'YY ...

# %% [markdown]
# With custom headers.

# %%
hdr = {'User-Agent': 'Mozilla/5.0'}

html = requests.get(url, headers=hdr)

html.content
# Out:
# b'\r\n\r\n<!doctype html>\n<html id="html" lang="en">\n<head><title>\r\n\t Ethereum (ETH) Blockchain Explorer\r\n</title><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="author" content="etherscan.io" /><meta name="Description" content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" /><meta name="keywords" content="ethereum, explorer, ether, search, blockchain, crypto, currency" /><meta name="format-detection" content="telephone=no" />\n<meta property="og:title" content=" Ethereum (ETH) Blockchain Explorer" /> <meta property="og:description" content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" /> <meta property="og:type" content="website" /> <meta property="og:site_name" content="Ethereum (ETH) Blockchain Explorer" /> <meta property="og:url" content="http://etherscan.io/" /> <meta property="og:image" content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" /> <meta property="og:image:url" content="https://etherscan.io/images/brandassets/etherscan-logo-r.jpg" /> <meta property="og:image:alt" content="Visit Etherscan.io" /> <meta name="twitter:card" content="summary" /> <meta name="twitter:title" content=" Ethereum (ETH) Blockchain Explorer" /> <meta property="twitter:description" content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" /> <meta name="twitter:site" content="@etherscan" /> <meta property="twitter:image" content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" />\n<link rel="shortcut icon" href="/images/favicon3.ico" />\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-T1JC9RNQXV"></script>\n<script>\r\n        window.dataLayer = window.dataLayer || [];\r\n        function gtag() { dataLayer.push(arguments); }\r\n        gtag(\'js\', new Date());\r\n        gtag(\'config\',\'G-T1JC9RNQXV\', { \'anonymize_ip\': true });\r\n    </script>\n<script>\r\n        //Search box text ad\r\n        var availableAd = [];\r\n        var gotAd = [];\r\n\r\n        \r\n        availableAd = ["<div class=\'p-2\'><a href=\'https://moonpay-affiliate-program.sjv.io/GmG56B\' rel=\'nofollow\' target=\'_blank\' data-bs-toggle=\'tooltip\' data-bs-trigger=\'hover\' title=\'Links to an External Advertiser site\' class=\'search-panel-ads d-flex align-items-center p-2 rounded\'><div class=\'me-2\'><img width=\'22\' class=\'rounded-1\' src=\'/images/gen/moonpay_20.png\' alt=\'Ads\'></div><div class=\'text-truncate\'><h6 class=\'d-flex align-items-center fs-sm text-dark mb-0\'><div class=\'text-truncate me-2\'>Moonpay: Buy & Sell Crypto with a credit card.</div><span class=\'d-none d-sm-inline-block small bg-white text-muted rounded-1 border px-2 py-1 ms-1\'>Sponsored</span><span class=\'d-inline-block d-sm-none small bg-white text-muted rounded-1 border px-2 py-1 ms-1\'>Ad</span></h6></div></a></div>", "<div class=\'p-2\'><a href=\'https://goto.etherscan.com/rd/V1343C63DX8YPRBPAX2C1G27C\' rel=\'nofollow\' target=\'_blank\' data-bs-toggle=\'tooltip\' data-bs-trigger=\'hover\' title=\'Links to an External Advertiser site\' class=\'search-panel-ads d-flex align-items-center p-2 rounded\'><div class=\'me-2\'><img width=\'22\' class=\'rounded-1\' src=\'/images/gen/solarx_20_2.png?v=2\' alt=\'SolarX\'></div><div class=\'text-truncate\'><h6 class=\'d-flex align-items-center fs-sm text-dark mb-0\'><div class=\'text-truncate me-2\'>SolarX: Mine with green energy. Buy on presale!</div><span class=\'d-none d-sm-inline-block small bg-white text-muted rounded-1 border px-2 py-1 ms-1\'>Sponsored</span><span class=\'d-inline-block d-sm-none small bg-white text-muted rounded-1 border  ...

# %% [markdown]
# Improved GET request.

# %%
import urllib.request

page = urllib.request.urlopen(url).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\frueffer\OneDrive - uni-mannheim.de\Desktop\DataScience\adsl\2_python_scraping\5_scraping_etherscan.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/frueffer/OneDrive%20-%20uni-mannheim.de/Desktop/DataScience/adsl/2_python_scraping/5_scraping_etherscan.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> import urllib.request
# ----> <a href='vscode-notebook-cell:/c%3A/Users/frueffer/OneDrive%20-%20uni-mannheim.de/Desktop/DataScience/adsl/2_python_scraping/5_scraping_etherscan.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> page = urllib.request.urlopen(url).read()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Improved GET request with custom headers.

# %%
from urllib.request import Request, urlopen

req = Request(url, headers = hdr)
page = urlopen(req)

# %% [markdown]
# Make soup.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page)
soup
# Out:
# <!DOCTYPE html>
# <html id="html" lang="en">
# <head><title>
# 	 Ethereum (ETH) Blockchain Explorer
# </title><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><meta content="etherscan.io" name="author"/><meta content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" name="Description"/><meta content="ethereum, explorer, ether, search, blockchain, crypto, currency" name="keywords"/><meta content="telephone=no" name="format-detection"/>
# <meta content=" Ethereum (ETH) Blockchain Explorer" property="og:title"/> <meta content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" property="og:description"/> <meta content="website" property="og:type"/> <meta content="Ethereum (ETH) Blockchain Explorer" property="og:site_name"/> <meta content="http://etherscan.io/" property="og:url"/> <meta content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" property="og:image"/> <meta content="https://etherscan.io/images/brandassets/etherscan-logo-r.jpg" property="og:image:url"/> <meta content="Visit Etherscan.io" property="og:image:alt"/> <meta content="summary" name="twitter:card"/> <meta content=" Ethereum (ETH) Blockchain Explorer" name="twitter:title"/> <meta content="Etherscan allows you to explore and search the Ethereum blockchain for transactions, addresses, tokens, prices and other activities taking place on Ethereum (ETH)" property="twitter:description"/> <meta content="@etherscan" name="twitter:site"/> <meta content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" property="twitter:image"/>
# <link href="/images/favicon3.ico" rel="shortcut icon"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-T1JC9RNQXV"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config','G-T1JC9RNQXV', { 'anonymize_ip': true });
#     </script>
# <script>
#         //Search box text ad
#         var availableAd = [];
#         var gotAd = [];
#
#
#         availableAd = ["<div class='p-2'><a href='https://moonpay-affiliate-program.sjv.io/GmG56B' rel='nofollow' target='_blank' data-bs-toggle='tooltip' data-bs-trigger='hover' title='Links to an External Advertiser site' class='search-panel-ads d-flex align-items-center p-2 rounded'><div class='me-2'><img width='22' class='rounded-1' src='/images/gen/moonpay_20.png' alt='Ads'></div><div class='text-truncate'><h6 class='d-flex align-items-center fs-sm text-dark mb-0'><div class='text-truncate me-2'>Moonpay: Buy & Sell Crypto with a credit card.</div><span class='d-none d-sm-inline-block small bg-white text-muted rounded-1 border px-2 py-1 ms-1'>Sponsored</span><span class='d-inline-block d-sm-none small bg-white text-muted rounded-1 border px-2 py-1 ms-1'>Ad</span></h6></div></a></div>", "<div class='p-2'><a href='https://goto.etherscan.com/rd/V1343C63DX8YPRBPAX2C1G27C' rel='nofollow' target='_blank' data-bs-toggle='tooltip' data-bs-trigger='hover' title='Links to an External Advertiser site' class='search-panel-ads d-flex align-items-center p-2 rounded'><div class='me-2'><img width='22' class='rounded-1' src='/images/gen/solarx_20_2.png?v=2' alt='SolarX'></div><div class='text-truncate'><h6 class='d-flex align-items-center fs-sm text-dark mb-0'><div class='text-truncate me-2'>SolarX: Mine with green energy. Buy on presale!</div><span class='d-none d-sm-inline-block small bg-white text-muted rounded-1 border px-2 py-1 ms-1'>Sponsored</span><span class='d-inline-block d-sm-none small bg-white text-muted rounded-1 border px-2 py-1 ms-1'>Ad</span></h6></div></a></div>"];
#         gotAd = ["ShowAds					"];
#
#     </script>
# <link href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="/assets/vendor/font-awesome/css/all.min.css?v=23.9.2.0" rel="stylesheet"/>
# <link href="/assets/vendor/autocomplete/dist/css/autocomplete.min.css?v=23.9.2.0" rel="stylesheet"/>
# <link href="/assets/css/theme.min.css?v=23.9.2.0" rel="stylesheet"/>
# <link href="/assets/css/custom.css?v=23.9.2.0" rel="stylesheet"/>
# <script src="/assets/vendor/jquery/dist/jquery.min.js?v=23.9.2.0"></script>
# <script src="/jss/blockies.js?v=23.9.2.0" type="text/javascript"></script>
# <script src="/assets/js/theme-appearance.js?v=23.9.2.0" type="text/javascript"></script>
# <style>
#         .autolink-safari a {
#             pointer-events: none !important;
#             text-decoration: none !important;
#             color: inherit !important;
#         }
#     </style>
# <style> .dchkivumhyt { -ms-flex-pack: center; justify-content: center; } .advr38hiypk { border-top: 1px solid #e7eaf3 !important; } body.dark-mode .advr38hiypk { border-color: #18365b !important; } @media (min-width: 992px) { .btlztnrzw2b { display: block !important; } } @media (min-width: 992px) { .ck2aebnvr1i { display: inline-block !important; } }  </style>
# <style type="text/css">#div-advert {line-height: 1.7}@media (max-width: 667px) {#div-advert {min-height: 62px;}}@media (max-width: 767px) {#div-advert {padding-bottom: 20px;}}</style>
# <style>
#         .wrapper {
#             background-color: #fff !important;
#         }
#
#         [data-bs-theme="light"],
#         [data-bs-theme=auto] {
#             --bg-img-wave: url(./assets/svg/patterns/waves.svg);
#         }
#
#         [data-bs-theme="dark"],
#         [data-bs-theme="dim"] {
#             --bg-img-wave: url(./assets/svg/patterns/waves-light.svg);
#         }
#     </style>
# </head>
# <body class="d-flex flex-column min-vh-100" id="body">
# <section id="masterNoticeBar">
# </section>
# <section class="d-none d-lg-block sticky-top bg-white border-bottom py-1" id="masterTopBar">
# <div class="container-xxl d-flex align-items-center justify-content-between">
# <div class="d-flex align-items-sm-center gap-4 w-100 fs-sm" id="ethPrice">
# <div class="text-muted"><span class="text-muted">ETH Price:</span> <a href="/chart/etherprice">$1,648.57</a><span data-bs-placement="top" data-bs-toggle="tooltip" title="Changes in the last 24 hours"><span class="text-danger"> (-1.03%)</span></span></div><div class="text-muted"><i class="fad fa-gas-pump me-1"></i> Gas: <span data-bs-html="true" data-bs-toggle="tooltip" id="spanGasTooltip" title="Base Fee: 11 Gwei&lt;br&gt;Priority Fee: 1 Gwei"><a href="/gastracker"><span class="gasPricePlaceHolder">12</span> Gwei</a></span></div>
# </div>
# <div class="d-flex justify-content-end align-items-center gap-2">
# <div class="dropdown" id="divThemeSetting">
# <button aria-expanded="false" class="btn btn-lg btn-white text-primary content-center" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="dropdownMenuTopbarSettings" style="width: 2.375rem; height: 2.375rem;" type="button">
# <span class="theme-btn-main"><i class="far fa-sun-bright theme-icon-active" data-href="#fa-sun-bright"></i></span>
# </button>
# <ul aria-labelledby="dropdownMenuTopbarSettings" class="dropdown-menu dropdown-menu-end">
# <li>
# <button class="dropdown-item theme-btn active" data-bs-theme-value="light" onclick="setThemeMode('light');" type="button">
# <i class="far fa-sun-bright fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-sun-bright"></i> Light
# </button>
# </li>
# <li>
# <button class="dropdown-item theme-btn" data-bs-theme-value="dim" onclick="setThemeMode('dim');" type="button">
# <i class="far fa-moon-stars fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon-stars"></i> Dim
# </button>
# </li>
# <li>
# <button class="dropdown-item theme-btn" data-bs-theme-value="dark" onclick="setThemeMode('dark');" type="button">
# <i class="far fa-moon fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon"></i> Dark
# </button>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/settings">
# <i class="far fa-gear fa-fw dropdown-item-icon me-1"></i> Site Settings <i class="far fa-arrow-right ms-1"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="dropdown" id="divTestNet">
# <button aria-expanded="false" class="btn btn-lg btn-white content-center" data-bs-toggle="dropdown" id="dropdownTopbarNetworks" style="width: 2.375rem; height: 2.375rem;" type="button">
# <img alt="Ethereum Logo" data-img-theme="light" src="/images/svg/brands/ethereum-original.svg" width="10"/>
# <img alt="Ethereum Logo" data-img-theme="darkmode" src="/images/svg/brands/ethereum-original-light.svg" width="10"/>
# </button>
# <ul aria-labelledby="dropdownTopbarNetworks" class="dropdown-menu dropdown-menu-end">
# <li>
# <a class="dropdown-item active active active" href="https://etherscan.io" id="LI_Mainnet">
# Ethereum Mainnet
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://cn.etherscan.com/?lang=zh-CN" id="LI_Mainnet_CN">
# Ethereum Mainnet <span class="badge border bg-light text-dark ms-1">CN</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://beaconscan.com/" id="LI2">
# Beaconscan <span class="badge border bg-light text-dark ms-1">ETH2</span>
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="https://goerli.etherscan.io" id="LI58">
# Goerli Testnet
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://sepolia.etherscan.io" id="LI9">
# Sepolia Testnet
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </section>
# <header class="header border-bottom d-print-none" id="masterHeader">
# <nav class="navbar navbar-expand-lg navbar-light py-3 py-lg-0">
# <div class="container-xxl position-relative">
# <a aria-label="Etherscan" class="navbar-brand" href="/" target="_parent">
# <img alt="Etherscan Logo" data-img-theme="light" src="/assets/svg/logos/logo-etherscan.svg?v=0.0.5" width="150"/>
# <img alt="Etherscan Logo" data-img-theme="darkmode" src="/assets/svg/logos/logo-etherscan-light.svg?v=0.0.5" width="150"/>
# </a>
# <div class="d-flex align-items-center gap-4">
# <a class="link-dark d-block d-lg-none" href="/login">
# <i class="far fa-user-circle me-1"></i> Sign In
# </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# </div>
# <div class="collapse navbar-collapse justify-content-end" id="navbarSupportedContent">
# <ul class="navbar-nav gap-1 gap-lg-0 pt-4 pt-lg-0">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="/" id="LI_default">
# Home
# </a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_blockchain" role="button">Blockchain</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <a class="dropdown-item" href="/txs" id="LI12">
# Transactions
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/txsPending" id="LI16">
# Pending Transactions
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/txsInternal" id="LI14">
# Contract Internal Transactions
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/txsBeaconDeposit" id="LI22">
# Beacon Deposits
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/txsBeaconWithdrawal" id="LI_BeaconWithdrawals">
# Beacon Withdrawals
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/blocks" id="LI_blocks">
# View Blocks
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/blocks_forked" id="LI_blocks2">
# Forked Blocks (Reorgs)
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/uncles" id="LI8">
# Uncles
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/accounts" id="LI_accountall">
# Top Accounts
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/contractsVerified" id="LI_contract_verified">
# Verified Contracts
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_tokens" role="button">Tokens</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <a class="dropdown-item" href="/tokens" id="LI21">
# Top Tokens <span class="small text-muted">(ERC-20)</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/tokentxns" id="LI1">
# Token Transfers <span class="small text-muted">(ERC-20)</span>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_Nfts" role="button">NFTs</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <a class="dropdown-item" href="/nft-top-contracts" id="LI63">
# Top NFTs
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/nft-top-mints" id="LI67">
# Top Mints
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/nft-trades" id="LI64">
# Latest Trades
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/nft-transfers" id="LI65">
# Latest Transfers
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/nft-latest-mints" id="LI66">
# Latest Mints
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_resources" role="button">Resources</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <a class="dropdown-item" href="/charts" id="LI_charts2">
# Charts And Stats
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/topstat" id="LI_topstat">
# Top Statistics
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/directory" id="LI62">
# Directory
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://info.etherscan.com/newsletters/" id="LI60">
# Newsletter
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://info.etherscan.com/" id="LI61">
# Knowledge Base
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="li_developers" role="button">Developers</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <a class="dropdown-item" href="/apis" id="LI5">
# API Plans
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://docs.etherscan.io/" id="LI6" target="_blank">
# API Documentation
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/code-reader" id="A1">
# Code Reader <span class="badge border bg-light text-muted">Beta</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/verifyContract" id="LI17">
# Verify Contract
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/find-similar-contracts" id="LI55">
# Similar Contract Search
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/searchcontract" id="LI53">
# Smart Contract Search
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/contractdiffchecker" id="LI54">
# Contract Diff Checker
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/vyper" id="LI27">
# Vyper Online Compiler
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/opcode-tool" id="LI24">
# Bytecode to Opcode
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/pushTx" id="LI10">
# Broadcast Transaction
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown position-initial">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_services2" role="button">More</a>
# <div class="dropdown-menu dropdown-menu-border dropdown-menu-mega">
# <div class="row">
# <div class="col-lg order-last order-lg-first">
# <div class="d-flex flex-column bg-light h-100 rounded-3 p-5">
# <div>
# <h6>Tools &amp; Services</h6>
# <p>Discover more of Etherscan's tools and services in one place.</p>
# </div>
# <div class="mt-auto">
# <p class="text-muted mb-2">Sponsored</p>
# <a href="https://chat.blockscan.com" target="_blank">
# <img alt="" data-img-theme="light" src="/images/svg/blockscan-logo-light.svg?v=0.0.5" width="140"/>
# <img alt="" data-img-theme="dim" src="/images/svg/blockscan-logo-dark.svg?v=0.0.5" width="140"/>
# <img alt="" data-img-theme="dark" src="/images/svg/blockscan-logo-dark.svg?v=0.0.5" width="140"/>
# </a>
# </div>
# </div>
# </div>
# <div class="col-sm py-5">
# <h6 class="px-3 mb-3">Tools</h6>
# <ul class="list-unstyled">
# <li>
# <a class="dropdown-item" href="/unitconverter" id="LI50">
# <i class="far fa-arrows-rotate dropdown-item-icon fa-fw me-1"></i>Unit Converter
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/exportData" id="LI51">
# <i class="far fa-download fa-fw me-1"></i>CSV Export
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/balancecheck-tool" id="LI52">
# <i class="far fa-file-invoice-dollar fa-fw me-1"></i>Account Balance Checker
# </a>
# </li>
# </ul>
# </div>
# <div class="col-sm py-5">
# <h6 class="px-3 mb-3">Explore</h6>
# <ul class="list-unstyled">
# <li>
# <a class="dropdown-item" href="/gastracker" id="LI19">
# <i class="far fa-gas-pump dropdown-item-icon fa-fw me-1"></i>Gas Tracker
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/dex" id="LI4">
# <i class="far fa-arrow-right-arrow-left dropdown-item-icon fa-fw me-1"></i>DEX Tracker
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/nodetracker" id="LI46">
# <i class="far fa-server dropdown-item-icon fa-fw me-1"></i>Node Tracker
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/labelcloud" id="LI41">
# <i class="far fa-signs-post dropdown-item-icon fa-fw me-1"></i>Label Cloud
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/name-lookup" id="LI26">
# <i class="far fa-magnifying-glass-chart dropdown-item-icon fa-fw me-1"></i>Domain Name Lookup
# </a>
# </li>
# </ul>
# </div>
# <div class="col-sm py-5">
# <h6 class="px-3 mb-3">Services</h6>
# <ul class="list-unstyled">
# <li>
# <a class="dropdown-item" href="/tokenapprovalchecker" id="LI49">
# <i class="far fa-shield-keyhole dropdown-item-icon fa-fw me-1"></i>Token Approvals <span class="badge border bg-light text-muted">Beta</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/verifiedSignatures" id="LI29">
# <i class="far fa-signature-lock dropdown-item-icon fa-fw me-1"></i>Verified Signature
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/idm">
# <i class="far fa-message-lines dropdown-item-icon fa-fw me-1"></i>Input Data Messages (IDM) <span class="badge border bg-light text-muted">Beta</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="/advanced-filter" id="LI31">
# <i class="far fa-filters dropdown-item-icon fa-fw me-1"></i>Advanced Filter <span class="badge border bg-light text-muted">Beta</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://chat.blockscan.com" target="_blank">
# <i class="far fa-messages dropdown-item-icon fa-fw me-1"></i>Blockscan Chat <i class="far fa-arrow-up-right-from-square text-muted ms-1"></i> <span class="badge border bg-light text-muted">Beta</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown d-block d-lg-none">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" role="button">Explorers</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <a class="dropdown-item active active active" href="https://etherscan.io" id="LI_Mainnet_1">
# Ethereum Mainnet
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://cn.etherscan.com/?lang=zh-CN" id="LI_Mainnet_CN_1">
# Ethereum Mainnet <span class="badge border bg-light text-dark ms-1">CN</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://beaconscan.com/" id="LI77">
# Beaconscan <span class="badge border bg-light text-dark ms-1">ETH2</span>
# </a>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="https://goerli.etherscan.io" id="LI78">
# Goerli Testnet
# </a>
# </li>
# <li>
# <a class="dropdown-item" href="https://sepolia.etherscan.io" id="LI79">
# Sepolia Testnet
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown d-block d-lg-none">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" role="button">Appearance &amp; Settings</a>
# <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
# <li>
# <button class="dropdown-item theme-btn active" data-bs-theme-value="light" onclick="setThemeMode('light');" type="button">
# <i class="far fa-sun-bright fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-sun-bright"></i> Light
# </button>
# </li>
# <li>
# <button class="dropdown-item theme-btn" data-bs-theme-value="dim" onclick="setThemeMode('dim');" type="button">
# <i class="far fa-moon-stars fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon-stars"></i> Dim
# </button>
# </li>
# <li>
# <button class="dropdown-item theme-btn" data-bs-theme-value="dark" onclick="setThemeMode('dark');" type="button">
# <i class="far fa-moon-stars fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon"></i> Dark
# </button>
# </li>
# <li>
# <hr class="dropdown-divider"/>
# </li>
# <li>
# <a class="dropdown-item" href="/settings">
# <i class="far fa-gear fa-fw dropdown-item-icon me-1"></i> Site Settings <i class="far fa-arrow-right ms-1"></i>
# </a>
# </li>
# </ul>
# </li>
# <li class="nav-item align-self-center d-none d-lg-block">
# <span class="text-secondary">|</span>
# </li>
# <li class="nav-item d-none d-lg-block">
# <a class="nav-link" href="/login">
# <i class="far fa-user-circle me-1"></i> Sign In
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <main class="main-content" id="content" role="main">
# <input id="hdnAgeText" name="hdnAgeText" type="hidden" value="Age"/>
# <input id="hdnDateTimeText" name="hdnDateTimeText" type="hidden" value="Date Time (UTC)"/>
# <input id="hdnAgeTitle" name="hdnAgeTitle" type="hidden" value="Click to show Age Format"/>
# <input id="hdnDateTimeTitle" name="hdnDateTimeTitle" type="hidden" value="Click to show Datetime Format"/>
# <input id="hdnTxnText" name="hdnTxnText" type="hidden" value="Txn Fee"/>
# <input id="hdnGasPriceText" name="hdnGasPriceText" type="hidden" value="Gas Price"/>
# <input id="hdnTxnFeeTitle" name="hdnTxnFeeTitle" type="hidden" value="(Gas Price * Gas Used by Txns) in Ether"/>
# <input id="hdnGasPriceTitle" name="hdnGasPriceTitle" type="hidden" value="Gas Price in Gwei"/>
# <section class="bg-dark pt-14 pb-20" style="background-image: url(/images/svg/waves-light.svg);">
# <div class="container-xxl">
# <div class="row justify-content-between align-items-center">
# <div class="col-md-9 col-lg-7 mb-5">
# <h1 class="fs-lg text-white fw-medium mb-3">
# The Ethereum Blockchain Explorer
# </h1>
# <form action="/search" class="mb-3" method="GET">
# <div class="search-panel-container bg-white border rounded d-flex gap-2 p-1.5">
# <div class="d-none d-sm-block">
# <select aria-label="Default select example" class="form-select fs-base border-0 filterby" name="f">
# <option selected="" value="0">All Filters</option>
# <option value="1">Addresses</option>
# <option value="2">Tokens</option>
# <option value="3">Name Tags</option>
# <option value="6">Domain Names</option>
# <option value="4">Labels</option>
# <option value="5">Websites</option>
# </select>
# </div>
# <div class="flex-grow-1 position-relative auto-search-max-height">
# <label class="visually-hidden" for="search-panel">Search</label>
# <input aria-describedby="button-header-search" autocomplete="off" class="form-control fs-base border-0 pe-8" id="search-panel" maxlength="68" name="q" onkeyup="handleSearchText(this);" placeholder="Search by Address / Txn Hash / Block / Token / Domain Name" spellcheck="false" type="text"/>
# <a class="clear-icon d-none align-items-center position-absolute top-0 bottom-0 my-auto d-flex align-items-center" href="javascript:;" style="right: 0.75rem; cursor:pointer;">
# <i class="fa-regular fa-xmark fs-5 text-secondary"></i>
# </a>
# <input id="hdnSearchText" type="hidden" value=""/>
# <input id="hdnSearchLabel" type="hidden" value=""/>
# <input id="hdnIsTestNet" type="hidden" value="False"/>
# </div>
# <div>
# <button class="btn fs-base btn-primary" type="submit">
# <i class="far fa-magnifying-glass"></i>
# </button>
# </div>
# </div>
# </form>
# <p class="text-white text-opacity-75 mb-0" style="min-height:22px">
# <ins data-revive-id="6452186c83cd256052c3c100f524ed97" data-revive-zoneid="6"></ins>
# <script async="" src="//kta.etherscan.com/www/d/asyncjses.php"></script>
# </p>
# </div>
# <div class="col-auto mx-auto">
# <div class="d-none d-lg-flex justify-content-center mt-n4">
# <a class="position-relative d-inline-block d-sm-none" href="https://goto.etherscan.com/rd/QAU1X87SS7W2MZ4UJTIUA7QSY" target="_blank">
# <span class="position-absolute bg-white text-dark shadow-sm rounded-1 small px-1" style="right: .75rem; top: -.5rem;">Ad</span>
# <img alt="Ad" class="img-fluid rounded" height="101" src="/images/gen/metawin_v8_321x101.png" width="321"/>
# </a>
# <a class="position-relative d-none d-sm-inline-block d-lg-none" href="https://goto.etherscan.com/rd/QAU1X87SS7W2MZ4UJTIUA7QSY" target="_blank">
# <span class="position-absolute bg-white text-dark shadow-sm rounded-1 small px-1" style="right: .75rem; top: -.5rem;">Ad</span>
# <img alt="Ad" class="img-fluid rounded" height="90" src="/images/gen/metawin_v8_730x90.png" width="730"/>
# </a>
# <a class="position-relative d-none d-lg-inline-block" href="https://goto.etherscan.com/rd/QAU1X87SS7W2MZ4UJTIUA7QSY" target="_blank">
# <span class="position-absolute bg-white text-dark shadow-sm rounded-1 small px-1" style="right: .75rem; top: -.5rem;">Ad</span>
# <img alt="Ad" class="img-fluid rounded" height="101" src="/images/gen/metawin_v8_321x101.png" width="321"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="container-xxl pb-20">
# <div class="card py-5 px-4 mb-4 mt-n12" id="ContentPlaceHolder1_mainboxes">
# <div class="row g-lg-10">
# <div class="col-md-6 col-lg-4">
# <div class="d-flex">
# <div class="text-center me-3" style="width: 1.5rem;">
# <img alt="Ethereum Logo" class="img-fluid mx-auto" data-img-theme="light" src="/images/svg/brands/ethereum-original.svg" width="18"/>
# <img alt="Ethereum Logo" class="img-fluid mx-auto" data-img-theme="darkmode" src="/images/svg/brands/ethereum-original-light.svg" width="18"/>
# </div>
# <div class="flex-grow-1">
# <div class="text-cap mb-px">Ether Price</div>
# <a class="link-dark fs-base" data-bs-placement="bottom" data-bs-toggle="tooltip" href="/chart/etherprice" rel="tooltip" title="View Historical Ether Price">$1,648.57<span class="text-muted"> @ 0.06052 BTC</span><span class="text-danger small"> (-1.03%)</span></a>
# </div>
# </div>
# <hr class="my-5"/>
# <div class="d-flex">
# <div class="me-3">
# <i class="fal fa-globe" style="font-size: 1.5rem;"></i>
# </div>
# <div class="flex-grow-1">
# <div class="text-cap mb-px">Market Cap</div>
# <a class="link-dark fs-base" href="/stat/supply">
# $198,201,338,492.00</a>
# </div>
# </div>
# </div>
# <div class="col-md-6 col-lg-4 border-md-start">
# <hr class="d-block d-md-none my-5"/>
# <div class="d-flex">
# <div class="me-3">
# <i class="fal fa-server" style="font-size: 1.5rem;"></i>
# </div>
# <div class="flex-grow-1">
# <div class="text-cap mb-px">Transactions</div>
# <a class="link-dark fs-base" data-bs-html="true" data-bs-placement="left" data-bs-toggle="tooltip" href="/txs" rel="tooltip" title="Total Transactions Counter&lt;br&gt;(Update every 5 mins)">2,099.36 M</a><span class="text-muted small" data-bs-placement="bottom" data-bs-toggle="tooltip" rel="tooltip" style="font-size:14px" title="Transactions per Second"> (11.7 TPS)</span>
# </div>
# <div class="text-end">
# <div class="text-cap mb-px">Med Gas Price</div>
# <a class="link-dark fs-base" data-bs-html="true" data-bs-toggle="tooltip" href="/gastracker" title="Base Fee: 11 Gwei&lt;br&gt;Priority Fee: 1 Gwei">12 Gwei <span class="text-muted small" style="font-size:14px">($0.42)</span></a>
# </div>
# </div>
# <hr class="my-5"/>
# <div class="d-flex">
# <div class="me-3">
# <i class="fal fa-gauge" style="font-size: 1.5rem;"></i>
# </div>
# <div class="flex-grow-1">
# <div class="text-cap mb-px">Last Finalized Block</div>
# <span class="fs-base" data-bs-placement="bottom" data-bs-toggle="tooltip" rel="tooltip" stake.="" title="This block is finalized and cannot be reverted without slashing at least 1/3 of all validators">18169754</span>
# </div>
# <div class="text-end">
# <div class="text-cap mb-px">Last Safe Block</div>
# <span class="fs-base" data-bs-placement="bottom" data-bs-toggle="tooltip" rel="tooltip" title="This block is safe and is unlikely to be reverted.">18169818</span>
# </div>
# </div>
# </div>
# <div class="col-lg-4 border-lg-start">
# <hr class="d-block d-lg-none my-5"/>
# <div class="text-cap mb-px">Transaction History in 14 days</div>
# <div class="w-100 pt-2" id="container-1" style="height: 105px;"></div>
# </div>
# </div>
# </div>
# <div class="d-flex d-lg-none justify-content-center mb-4">
# <a class="position-relative d-inline-block d-sm-none" href="https://goto.etherscan.com/rd/QAU1X87SS7W2MZ4UJTIUA7QSY" target="_blank">
# <span class="position-absolute bg-white text-dark shadow-sm rounded-1 small px-1" style="right: .75rem; top: -.5rem;">Ad</span>
# <img alt="Ad" class="img-fluid rounded" height="101" src="/images/gen/metawin_v8_321x101.png" width="321"/>
# </a>
# <a class="position-relative d-none d-sm-inline-block d-lg-none" href="https://goto.etherscan.com/rd/QAU1X87SS7W2MZ4UJTIUA7QSY" target="_blank">
# <span class="position-absolute bg-white text-dark shadow-sm rounded-1 small px-1" style="right: .75rem; top: -.5rem;">Ad</span>
# <img alt="Ad" class="img-fluid rounded" height="90" src="/images/gen/metawin_v8_730x90.png" width="730"/>
# </a>
# <a class="position-relative d-none d-lg-inline-block" href="https://goto.etherscan.com/rd/QAU1X87SS7W2MZ4UJTIUA7QSY" target="_blank">
# <span class="position-absolute bg-white text-dark shadow-sm rounded-1 small px-1" style="right: .75rem; top: -.5rem;">Ad</span>
# <img alt="Ad" class="img-fluid rounded" height="101" src="/images/gen/metawin_v8_321x101.png" width="321"/>
# </a>
# </div>
# <div class="row gx-4">
# <div class="col-lg-6 mb-4">
# <div class="card">
# <div class="card-header">
# <h2 class="card-header-title">Latest Blocks</h2>
# </div>
# <div class="card-body overflow-auto scrollbar-custom" id="mCSB_1_container" style="max-height: 30.3rem;">
# <div class="row"><div class="col-sm-4"><div class="d-flex align-items-center gap-2"><div class="d-none d-sm-flex content-center bg-light text-muted rounded p-3" style="height: 3rem; width: 3rem;"><i class="fal fa-cube fs-lg"></i></div><div class="d-flex flex-row flex-sm-column align-items-center align-items-sm-start gap-1 gap-sm-0"><span class="d-inline-block d-sm-none">Block</span><a class="text-truncate" href="/block/18169846" style="max-width: 6rem;">18169846</a><div class="small text-muted"> 5 secs ago</div></div></div></div><div class="col-sm-8 d-flex justify-content-sm-between align-items-end align-items-sm-center position-relative"><div class="pe-0 pe-sm-2"><div class="d-flex flex-wrap gap-1">Fee Recipient <a class="text-truncate d-block" data-bs-toggle="tooltip" href="/address/0xdafea492d9c6733ae3d56b7ed1adb60692c98bc5" style="max-width: 8rem;" title="0xdafea492d9c6733ae3d56b7ed1adb60692c98bc5">Flashbots: Builder</a></div><a data-bs-toggle="tooltip" href="/txs?block=18169846" title="Transactions in this Block">139 txns </a> <span class="small text-muted me-2">in 12 secs</span><span class="d-inline-block d-sm-none badge border border-dark dark:border-white border-opacity-15 text-dark fw-medium py-1 py-sm-1.5 px-1.5 px-sm-2" data-bs-toggle="tooltip" title="Block Reward">0<b>.</b>03095 Eth</span></div><div class="d-none d-sm-block text-end ms-2 ms-sm-0"><span class="badge border border-dark dark:border-white border-opacity-15 text-dark fw-medium py-1.5 px-2" data-bs-toggle="tooltip" title="Block Reward">0<b>.</b>03095 Eth</span></div></div></div><hr/><div class="row"><div class="col-sm-4"><div class="d-flex align-items-center gap-2"><div class="d-none d-sm-flex content-center bg-light text-muted rounded p-3" style="height: 3rem; width: 3rem;"><i class="fal fa-cube fs-lg"></i></div><div class="d-flex flex-row flex-sm-column align-items-center align-items-sm-start gap-1 gap-sm-0"><span class="d-inline-block d-sm-none">Block</span><a class="text-truncate" href="/block/18169845" style="max-width: 6rem;">18169845</a><div class="small text-muted"> 17 secs ago</div></div></div></div><div class="col-sm-8 d-flex justify-content-sm-between align-items-end align-items-sm-center position-relative"><div class="pe-0 pe-sm-2"><div class="d-flex flex-wrap gap-1">Fee Recipient <a class="text-truncate d-block" data-bs-toggle="tooltip" href="/address/0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97" style="max-width: 8rem;" title="0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97">Titan Builder</a></div><a data-bs-toggle="tooltip" href="/txs?block=18169845" title="Transactions in this Block">171 txns </a> <span class="small text-muted me-2">in 12 secs</span><span class="d-inline-block d-sm-none badge border border-dark dark:border-white border-opacity-15 text-dark fw-medium py-1 py-sm-1.5 px-1.5 px-sm-2" data-bs-toggle="tooltip" title="Block Reward">0<b>.</b>03164 Eth</span></div><div class="d-none d-sm-block text-end ms-2 ms-sm-0"><span class="badge border border-dark dark:border-white border-opacity-15 text-dark fw-medium py-1.5 px-2" data-bs-toggle="tooltip" title="Block Reward">0<b>.</b>03164 Eth</span></div></div></div><hr/><div class="row"><div class="col-sm-4"><div class="d-flex align-items-center gap-2"><div class="d-none d-sm-flex content-center bg-light text-muted rounded p-3" style="height: 3rem; width: 3rem;"><i class="fal fa-cube fs-lg"></i></div><div class="d-flex flex-row flex-sm-column align-items-center align-items-sm-start gap-1 gap-sm-0"><span class="d-inline-block d-sm-none">Block</span><a class="text-truncate" href="/block/18169844" style="max-width: 6rem;">18169844</a><div class="small text-muted"> 29 secs ago</div></div></div></div><div class="col-sm-8 d-flex justify-content-sm-between align-items-end align-items-sm-center position-relative"><div class="pe-0 pe-sm-2"><div class="d-flex flex-wrap gap-1">Fee Recipient <a class="text-truncate d-block" data-bs-toggle="tooltip" href="/address/0x4838b106fce9647bdf1e7877bf73ce8b0bad5f97" ...
# </div>
# <a class="card-footer bg-light fw-medium text-cap link-muted text-center" href="/blocks">
# View all blocks <i class="far fa-long-arrow-right ms-1"></i>
# </a>
# </div>
# </div>
# <div class="col-lg-6">
# <div class="card">
# <div class="card-header">
# <h2 class="card-header-title">Latest Transactions</h2>
# </div>
# <div class="card-body overflow-auto scrollbar-custom" id="mCSB_2_container" style="max-height: 30.3rem;">
-1 py-1.5 px-2 fw-medium">0<b>.</b>01668 Eth</span></div></div><div class="d-none d-sm-block text-end ms-2 ms-sm-0" data-bs-toggle="tooltip" title="Amount"><span class="badge border border-dark dark:border-white border-opacity-15 text-dark py-1.5 px-2 fw-medium">0<b>.</b>01668 Eth</span></div></div></div><hr/><div class="row"><div class="col-sm-4 col-lg-5"><div class="d-flex align-items-center gap-2"><div class="d-none d-sm-flex content-center bg-light text-muted rounded p-3" style="height: 3rem; width: 3rem;"><i class="fal fa-memo fs-lg"></i></div><div class="d-flex align-items-center align-items-sm-start flex-row flex-sm-column gap-1 gap-sm-0"><span class="d-inline-block d-sm-none">TX#</span><a class="d-block text-truncate" href="/tx/0xc36a898daf815e9bd0a309cf3d557866c7bdeb9f1c70fd214fb203f99892e4a9" style="max-width: 8rem;">0xc36a898daf815e9bd0a309cf3d557866c7bdeb9f1c70fd214fb203f99892e4a9</a><div class="small text-muted">5 secs ago</div></div></div></div><div class="col-sm-8 col-lg-7 d-flex justify-content-sm-between align- ...
# </div>
# <a class="card-footer bg-light fw-medium text-cap link-muted text-center" href="/txs">
# View all transactions <i class="far fa-long-arrow-right ms-1"></i>
# </a>
# </div>
# </div>
# </div>
# </section>
# </main>
# <div id="push" style="display: none;"></div>
# <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal fade" id="emailSubscribeModalBox" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-sm" role="document">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close close-md" data-bs-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <div class="text-center py-5-alt px-4">
# <div id="emailSubscribeModalBoxText"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="copyAddressConfirmModal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-md">
# <div class="modal-content">
# <div class="modal-header border-0">
# <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body pt-0">
# <div class="mb-5">
# <div class="text-center">
# <div class="mb-2">
# <i class="fas fa-exclamation-triangle text-warning fs-2"></i>
# </div>
# <h6 class="modal-title fs-5 mb-0">Before You Copy</h6>
# </div>
# <div class="mb-3 text-center">
# <p class="text-muted small" id="addressToCopy"></p>
# </div>
# <p id="copyAddressConfirmMessage"></p>
# <div class="form-check">
# <input class="form-check-input" id="popupDontShowAgain" type="checkbox" value=""/>
# <label class="form-check-label" for="popupDontShowAgain">Don't show this for 30 days</label>
# </div>
# </div>
# <div class="text-center">
# <button class="btn btn-lg btn-secondary" data-bs-dismiss="modal" data-clipboard-target="#addressToCopy" id="btnConfirmCopyAddress" type="button">
# Understand, Copy Address
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="bg-light mt-auto d-print-none" id="masterFooter">
# <div class="container-xxl">
# <div class="d-flex justify-content-between align-items-baseline py-6">
# <div class="d-flex gap-2">
# <a class="btn btn-sm btn-secondary content-center rounded-circle" data-bs-placement="top" data-bs-toggle="tooltip" data-bs-trigger="hover" href="https://twitter.com/etherscan" rel="nofollow noopener" style="width: 2rem; height: 2rem;" target="_blank" title="Twitter">
# <i class="fab fa-twitter"></i>
# </a>
# <a class="btn btn-sm btn-secondary content-center rounded-circle" data-bs-placement="top" data-bs-toggle="tooltip" data-bs-trigger="hover" href="https://medium.com/etherscan-blog" rel="nofollow noopener" style="width: 2rem; height: 2rem;" target="_blank" title="Medium">
# <i class="fab fa-medium"></i>
# </a>
# <a class="btn btn-sm btn-secondary content-center rounded-circle" data-bs-placement="top" data-bs-toggle="tooltip" data-bs-trigger="hover" href="https://www.facebook.com/etherscan/" rel="nofollow noopener" style="width: 2rem; height: 2rem;" target="_blank" title="Facebook">
# <i class="fab fa-facebook"></i>
# </a>
# <a class="btn btn-sm btn-secondary content-center rounded-circle" data-bs-placement="top" data-bs-toggle="tooltip" data-bs-trigger="hover" href="https://www.reddit.com/r/etherscan/" rel="nofollow noopener" style="width: 2rem; height: 2rem;" target="_blank" title="Reddit">
# <i class="fab fa-reddit-alien"></i>
# </a>
# </div>
# <a class="link-dark" href="#">
# <i class="far fa-arrow-up-to-line me-1"></i>Back to Top
# </a>
# </div>
# <hr class="my-0"/>
# <div class="row justify-content-md-between py-8 py-lg-10">
# <div class="col-lg-4 pe-xl-16 mb-4 mb-lg-0">
# <div class="d-flex align-items-center mb-3">
# <img alt="Ethereum Logo" class="me-2" data-img-theme="light" src="/images/svg/brands/ethereum-original.svg" width="20"/>
# <img alt="Ethereum Logo" class="me-2" data-img-theme="darkmode" src="/images/svg/brands/ethereum-original-light.svg" width="20"/>
# <span class="fs-5">Powered by Ethereum</span>
# </div>
# <p class="fs-sm">Etherscan is a Block Explorer and Analytics Platform for Ethereum, a decentralized smart contracts platform.</p>
# <div class="d-none d-lg-block mt-n4 mb-n6">
# <img alt="Background Map Image" class="opacity-50" data-img-theme="light" src="/images/map.png" width="280"/>
# <img alt="Background Map Image" class="opacity-50" data-img-theme="darkmode" src="/images/map-light.png" width="280"/>
# </div>
# </div>
# <div class="col-6 col-md-4 col-lg mb-10 mb-md-0">
# <h4 class="h6 mb-3">Company</h4>
# <ul class="list-unstyled list-sm-space fs-sm mb-0">
# <li><a class="link-dark" href="/aboutus">About Us</a></li>
# <li><a class="link-dark" href="/brandassets">Brand Assets</a></li>
# <li><a class="link-dark" href="/contactus">Contact Us</a></li>
# <li>
# <a class="link-dark" href="/careers">
# <span class="me-1">Careers</span> <span class="bg-primary text-white small fw-medium text-nowrap rounded-pill p-1 px-2">We're Hiring!</span>
# </a>
# </li>
# <li><a class="link-dark" href="/terms">Terms of Service</a></li>
# <li><a class="link-dark" href="/bugbounty">Bug Bounty</a></li>
# </ul>
# </div>
# <div class="col-6 col-md-4 col-lg mb-10 mb-md-0">
# <h4 class="h6 mb-3">Community</h4>
# <ul class="list-unstyled list-sm-space fs-sm mb-0">
# <li><a class="link-dark" href="https://docs.etherscan.io/" target="_blank">API Documentation</a></li>
# <li><a class="link-dark" href="https://info.etherscan.com/">Knowledge Base</a></li>
# <li><a class="link-dark" href="https://etherscan.freshstatus.io/" rel="nofollow noopener" target="_blank">Network Status</a></li>
# <li><a class="link-dark" href="https://info.etherscan.com/newsletters/">Newsletters</a></li>
# <li><a class="link-dark" href="/comments">Disqus Comments</a></li>
# </ul>
# </div>
# <div class="col-6 col-md-4 col-lg">
# <h4 class="h6 mb-3">Products &amp; Services</h4>
# <ul class="list-unstyled list-sm-space fs-sm mb-0">
# <li><a class="link-dark" href="/contactusadvertise">Advertise</a></li>
# <li><a class="link-dark" href="/eaas">Explorer-as-a-Service (EaaS)</a></li>
# <li><a class="link-dark" href="/apis">API Plans</a></li>
# <li><a class="link-dark" href="/prioritysupport">Priority Support</a></li>
# <li><a class="link-dark" href="https://blockscan.com" target="_blank">Blockscan <i class="far fa-arrow-up-right-from-square text-muted ms-1"></i></a></li>
# <li><a class="link-dark" href="https://chat.blockscan.com/start" target="_blank">Blockscan Chat <i class="far fa-arrow-up-right-from-square text-muted ms-1"></i></a></li>
# </ul>
# </div>
# </div>
# <div class="border-top py-4">
# <div class="row justify-content-between align-items-center fs-sm">
# <div class="col-md mb-2 mb-md-0">
# <p class="mb-0">Etherscan © 2023 (C1)</p>
# </div>
# <div class="col-md text-md-end">
# <p class="mb-0">
# Donations: <a class="me-1" href="/address/0x71c7656ec7ab88b098defb751b7401b5f6d8976f"><span id="spanDonateAddress" runat="server">0x71c765...d8976f</span></a> <i class="fas fa-heart text-danger"></i>
# </p>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div id="masterDivCookie">
# <div class="fixed-bottom text-center" id="divcookie" style="display: none;">
# <div class="alert alert-light fade show border shadow-sm d-inline-flex flex-wrap flex-sm-nowrap align-items-sm-center text-start gap-3 mx-3" role="alert">
# <p class="text-dark mb-0">
# <i class="far fa-cookie-bite text-muted"></i> This website <a href="/terms#cookiestatement" target="_blank">uses cookies to improve your experience</a>. By continuing to use this website, you agree to its <a href="/terms" target="_blank">Terms</a> and <a href="/privacyPolicy" target="_blank">Privacy Policy</a>.
# </p>
# <button aria-label="Close" class="btn btn-primary text-nowrap px-4" data-bs-dismiss="alert" id="btnCookie" type="button">Got it!</button>
# </div>
# </div>
# </div>
# <script src="/assets/vendor/jquery-ui/jquery-ui.min.js?v=23.9.2.0"></script>
# <script src="/assets/vendor/jquery-migrate/dist/jquery-migrate.min.js?v=23.9.2.0"></script>
# <script src="/assets/vendor/bootstrap/bootstrap.bundle.min.js?v=23.9.2.0"></script>
# <script src="/assets/vendor/cubeportfolio/js/jquery.cubeportfolio.min.js?v=23.9.2.0"></script>
# <script src="/assets/vendor/clipboard/dist/clipboard.min.js?v=23.9.2.0"></script>
# <script src="/assets/js/hs.core.js?v=23.9.2.0"></script>
# <script src="/assets/js/components/hs.cubeportfolio.js?v=23.9.2.0"></script>
# <script src="/assets/js/custom/combine-js-bottom2.js?v=23.9.2.0"></script>
# <script src="/assets/vendor/autocomplete/dist/js/autocomplete.min.js?v=23.9.2.0"></script>
# <script src="/assets/js/custom/ether-search.js?v=23.9.2.0"></script>
# <script src="/assets/js/app.min.js?v=23.9.2.0"></script>
# <script>
#         (function () {
#             // INITIALIZATION OF CLIPBOARD
#             HSCore.components.HSClipboard.init('.js-clipboard');
#
#             let searchAttributes = {
#                 'name': 'title',
#                 'img': 'img',
#                 'rate': 'rate',
#                 'address': 'address',
#                 'link': 'link',
#                 'group': 'group',
#                 'groupid': 'groupid',
#                 'website': 'website',
#                 'is_verified': 'is_checked',
#                 'ps': 'ps',
#                 'desc': 'desc',
#                 'reputation' : 'reputation'
#             }
#
#             etherSearchInit({
#                 id: 'search-panel',
#                 attributes: searchAttributes
#             });
#         })();
#
#
#     </script>
# <script>
#         $(window).on('load', function () {
#             myfn_subscribeNewsletter.startFn("#btnSubscribeNewsletter", "#signupSrEmail")
#         });
#
#         $(document).on('ready', function () {
#             // initialization of cubeportfolio
#             $.HSCore.components.HSCubeportfolio.init('.cbp');
#
#             const clipboard = new ClipboardJS('.js-clipboard');
#             clipboard.on('success', function (e) {
#                 let toolTip = bootstrap.Tooltip.getInstance(e.trigger);
#                 var oriTooltip = toolTip._config.originalTitle
#
#                 toolTip._config.title = 'Copied!';
#                 toolTip.setContent();
#                 toolTip.update();
#
#                 setTimeout(function () {
#                     toolTip._config.title = oriTooltip;
#                 }, 1000);
#             });
#         });
#
#     </script>
# <script type="text/javascript">
#         var sid = 'f7cf383f5e01ced01085ce0420ad2a67';
#         var strGlobal = getCookie("etherscan_switch_age_datetime");
#         var strGlobalFee = sessionStorage.getItem("ShowFee");
#         var cookieconsent = getCookie("etherscan_cookieconsent");
#         var ignoreCopyConfirmation = getCopyAddressConfirmationSetting();
#
#         if (cookieconsent !== "True" && document.getElementById("divcookie")) {
#             document.getElementById("divcookie").style.display = "block";
#         };
#
#
#         function getCookie(cname) {
#             var name = cname + "=";
#             var ca = document.cookie.split(';');
#             for (var i = 0; i < ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) === ' ') {
#                     c = c.substring(1);
#                 }
#                 if (c.indexOf(name) === 0) {
#                     return c.substring(name.length, c.length);
#                 }
#             }
#             return "";
#         }
#
#         $("#btnCookie").click(function () {
#             $("#divcookie").fadeOut("slow", function () {
#                 var d = new Date();
#                 d.setTime(d.getTime() + (1095 * 24 * 60 * 60 * 1000));
#                 var expires = "expires=" + d.toUTCString();
#                 document.cookie = "etherscan_cookieconsent=True" + ";" + expires + ";path=/";;
#             });
#         });
#
#         function handleSearchText(data) {
#             searchAddress = false;
#             if ($("search-panel").val() == "") {
#                 $("#hdnSearchText").val("");
#                 $("#hdnSearchLabel").val("");
#             }
#         }
#
#         function writeCookie(key, value, days) {
#             var date = new Date();
#             days = days || 365;
#             date.setTime(+ date + (days * 86400000));
#             window.document.cookie = key + "=" + value + "; expires=" + date.toGMTString() + "; path=/";
#             return value;
#         }
#
#         function setThemeMode(mode) {
#             writeCookie('displaymode', mode);
#         }
#
#         // Note: this function will be called from where need to init the "Copy Address Confirm Modal".
#         function openCopyAddressConfirmModal(address, message) {
#             $("#addressToCopy").text(address);
#             $("#copyAddressConfirmMessage").text(message);
#
#             const clipboard = new ClipboardJS("#btnConfirmCopyAddress");
#             document.getElementById('copyAddressConfirmModal').addEventListener('hidden.bs.modal', event => {
#                 clipboard.destroy();
#             });
#
#             const copyAddressConfirmModal = new bootstrap.Modal('#copyAddressConfirmModal', {
#                 backdrop: true
#             })
#             copyAddressConfirmModal.show();
#         }
#
#         function saveCopyAddressConfirmationSetting(ignoreCopyConfirmation) {
#             const copyAddressConfirmationSetting = {
#                 ignoreCopyConfirmation: ignoreCopyConfirmation,
#                 expiresOn: Date.now() + 1000 * 60 * 60 * 24 * 30
#             };
#             localStorage.setItem("copyAddressConfirmationSetting", JSON.stringify(copyAddressConfirmationSetting));
#         }
#
#         function getCopyAddressConfirmationSetting() {
#             try {
#                 const settings = localStorage.getItem("copyAddressConfirmationSetting");
#                 if (settings) {
#                     const copyAddressConfirmationSetting = JSON.parse(settings);
#
#                     return copyAddressConfirmationSetting.ignoreCopyConfirmation && copyAddressConfirmationSetting.expiresOn > Date.now();
#                 }
#                 else {
#                     return false;
#                 }
#             } catch (e) {
#                 console.log(e);
#                 return false;
#             }
#         }
#
#     </script>
# <script src="/assets/highcharts/v/highcharts.js?v=23.9.2.0"></script>
# <script>
#         var lang_miner = "Fee Recipient";
#         var lang_mined_by = "Mined by";
#         var lang_block = "Block";
#         var lang_block_reward = "Block Reward";
#         var lang_sec = "sec";
#         var lang_secs = "secs";
#         var lang_min = "min";
#         var lang_mins = "mins";
#         var lang_from = "From";
#         var lang_to = "To";
#         var lang_amount = "Amount";
#         var lang_tx = "Tx";
#         var lang_bk = "Bk";
#         var lang_ether = "Eth";
#         var lang_txns = "txns";
#         var lang_in_X = "in";
#         var lang_ago = "ago";
#         var lang_secs_ago = "less than 1 sec ago";
#         var lang_sec_ago = "sec ago";
#         var lang_sec_in = "";
#     </script>
# <script type="text/javascript">
#         $(function () {
#             $('#container-1').highcharts({
#                 chart: {
#                     spacingTop: 10,
#                     spacingBottom: 0,
#                     spacingLeft: 0,
#                     spacingRight: 10,
#                 },
#
#                 title: {
#                     text: '',
#                     align: 'left',
#                 },
#
#                 xAxis: {
#                     title: { text: '' },
#                     lineWidth: 0,
#                     minorTickLength: 0,
#                     tickLength: 0,
#                     labels: {
#                         step: 7,
#                     },
#                     categories: [
#                         'Sep 4','Sep 5','Sep 6','Sep 7','Sep 8','Sep 9','Sep 10','Sep 11','Sep 12','Sep 13','Sep 14','Sep 15','Sep 16','Sep 17','Sep 18',
#                     ]
#                 },
#
#                 yAxis: {
#                     labels: {
#                         enabled: true
#                     },
#                     gridLineWidth: 0,
#                     title: {
#                         text: null
#                     }
#                 },
#
#                 legend: {
#                     enabled: false
#                 },
#
#                 credits: {
#                     enabled: false
#                 },
#
#                 tooltip: {
#                     formatter: function () {
#                         return '<span style="font-size:10px">' + this.point.friendlydate + '</span><br><table class="text-dark"><tr><td style="padding:0">' +
#                             '<span class="text-dark">Transactions: </a></span><b>' + this.point.formattedValue + '</b><br>' +
#                             '<br>' + 'Price: ' + this.point.price + ''
#                         '</td></tr></table>';
#                     }
#                 },
#
#                 accessibility: {
#                     enabled: false
#                 },
#
#                 plotOptions: {
#                     series: {
#                         color: '#1e2022',
#                         enableMouseTracking: true,
#                         lineWidth: 1,
#                         shadow: false,
#                         animation: false,
#                         cursor: 'pointer',
#                         states: {
#                             hover: {
#                                 lineWidth: 1
#                             }
#                         },
#                         marker: {
#                             radius: 0
#                         },
#                         point: {
#                             events: {
#                                 select: function (e) {
#                                     location.href = 'txs?dt=' + this.options.dt;
#                                 }
#                             }
#                         }
#                     },
#                     column: {
#                         pointPadding: 0.1,
#                         borderWidth: 0
#                     }
#                 },
#
#                 series: [{
#                     name: 'Transactions',
#                     type: 'spline',
#                     data: [{y : 952440, dt : '1693785600', formattedValue : '952,440', friendlydate : 'Monday, September 4, 2023', price : '$1,629.77'  },{y : 994049, dt : '1693872000', formattedValue : '994,049', friendlydate : 'Tuesday, September 5, 2023', price : '$1,633.84'  },{y : 1058940, dt : '1693958400', formattedValue : '1,058,940', friendlydate : 'Wednesday, September 6, 2023', price : '$1,632.35'  },{y : 1017089, dt : '1694044800', formattedValue : '1,017,089', friendlydate : 'Thursday, September 7, 2023', price : '$1,647.63'  },{y : 1014297, dt : '1694131200', formattedValue : '1,014,297', friendlydate : 'Friday, September 8, 2023', price : '$1,636.13'  },{y : 929400, dt : '1694217600', formattedValue : '929,400', friendlydate : 'Saturday, September 9, 2023', price : '$1,635.28'  },{y : 866548, dt : '1694304000', formattedValue : '866,548', friendlydate : 'Sunday, September 10, 2023', price : '$1,616.80'  },{y : 1021616, dt : '1694390400', formattedValue : '1,021,616', friendlydate : 'Monday, September 11, 2023', price : '$1,551.73'  },{y : 1092958, dt : '1694476800', formattedValue : '1,092,958', friendlydate : 'Tuesday, September 12, 2023', price : '$1,593.01'  },{y : 1627860, dt : '1694563200', formattedValue : '1,627,860', friendlydate : 'Wednesday, September 13, 2023', price : '$1,607.99'  },{y : 1071590, dt : '1694649600', formattedValue : '1,071,590', friendlydate : 'Thursday, September 14, 2023', price : '$1,627.01'  },{y : 1002709, dt : '1694736000', formattedValue : '1,002,709', friendlydate : 'Friday, September 15, 2023', price : '$1,641.48'  },{y : 922374, dt : '1694822400', formattedValue : '922,374', friendlydate : 'Saturday, September 16, 2023', price : '$1,634.86'  },{y : 879624, dt : '1694908800', formattedValue : '879,624', friendlydate : 'Sunday, September 17, 2023', price : '$1,623.06'  },{y : 979571, dt : '1694995200', formattedValue : '979,571', friendlydate : 'Monday, September 18, 2023', price : '$1,637.93'  },],
#                     allowPointSelect: true,
#                     pointStart: 0
#                 }]
#             });
#         });
#     </script>
# <script type="text/javascript">
#
#         function setFocus() {
#             if (window.innerWidth > 600)
#                 $("input[name=q]").focus();
#         }
#         $(document).ready(function () {
#             //setFocus();
#         });
#     </script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'8091b39e5dc02c0d',t:'MTY5NTEyNTE3Ni4zNDcwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
# Import selenium
# !pip install webdriver_manager
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
# Out:
# Collecting webdriver_manager
#   Obtaining dependency information for webdriver_manager from https://files.pythonhosted.org/packages/19/5a/a16653bfce685c9832217d377f52065351eeac9862e44e2996cd81f3bb4d/webdriver_manager-4.0.0-py2.py3-none-any.whl.metadata
#   Downloading webdriver_manager-4.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from webdriver_manager) (2.31.0)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from webdriver_manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->webdriver_manager) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->webdriver_manager) (2023.7.22)
# Downloading webdriver_manager-4.0.0-py2.py3-none-any.whl (27 kB)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.0 webdriver_manager-4.0.0

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (2.0.4)
# Requirement already satisfied: trio~=0.17 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (0.10.4)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio-websocket~=0.9->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\frueffer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# Load driver

from selenium.webdriver.chrome.options import Options
options = Options()
options.add_argument("--headless")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
# !pip install Chrome
# Out:
# ERROR: Could not find a version that satisfies the requirement Chrome (from versions: none)
# ERROR: No matching distribution found for Chrome

# %%
driver.get(url)

# %% [markdown]
# Finding one specific element with XPath and class name.
#
# _Note: the browser can export these selectors._

# %%
# CSS selector not available in Selenium.
# #mCSB_1_container > div:nth-child(1) > div.col-sm-4 > div > div.d-flex.flex-row.flex-sm-column.align-items-center.align-items-sm-start.gap-1.gap-sm-0 > a

my_xpath = '//*[@id="mCSB_1_container"]/div[1]/div[1]/div/div[2]/a'

elem = driver.find_element(By.XPATH, my_xpath)

# %%
elem.text
# Out:
# '18169849'

# %%
elem = driver.find_element(By.CLASS_NAME, 'hash-tag')

elem.text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\frueffer\OneDrive - uni-mannheim.de\Desktop\DataScience\adsl\2_python_scraping\5_scraping_etherscan.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/frueffer/OneDrive%20-%20uni-mannheim.de/Desktop/DataScience/adsl/2_python_scraping/5_scraping_etherscan.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> elem = driver.find_element(By.CLASS_NAME, 'hash-tag')
#       <a href='vscode-notebook-cell:/c%3A/Users/frueffer/OneDrive%20-%20uni-mannheim.de/Desktop/DataScience/adsl/2_python_scraping/5_scraping_etherscan.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> elem.text
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:738, in WebDriver.find_element(self, by, value)
#     735     by = By.CSS_SELECTOR
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".hash-tag"}
#   (Session info: chrome=116.0.5845.188); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x007B37C3+48947]
# 	(No symbol) [0x00748551]
# 	(No symbol) [0x0064C92D]
# 	(No symbol) [0x00679E38]
# 	(No symbol) [0x00679EFB]
# 	(No symbol) [0x006A8EF2]
# 	(No symbol) [0x006950D4]
# 	(No symbol) [0x006A75DA]
# 	(No symbol) [0x00694E86]
# 	(No symbol) [0x006716C7]
# 	(No symbol) [0x0067284D]
# 	GetHandleVerifier [0x009FFDF9+2458985]
# 	GetHandleVerifier [0x00A4744F+2751423]
# 	GetHandleVerifier [0x00A41361+2726609]
# 	GetHandleVerifier [0x00830680+560624]
# 	(No symbol) [0x0075238C]
# 	(No symbol) [0x0074E268]
# 	(No symbol) [0x0074E392]
# 	(No symbol) [0x007410B7]
# 	BaseThreadInitThunk [0x777500C9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C87B4E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C87B1E+238]

# %%
elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')

# %%
type(elements), len(elements)
# Out:
# (list, 90)

# %% [markdown]
# #### All transactions
#
# Let's now get all transactions, not just what is on the home page.

# %%
url = 'https://etherscan.io/txs'

# %% [markdown]
# By visual inspection in DevTools, each row contains 3 elements:
# - transaction hash
# - from
# - to

# %%
driver.get(url)
elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')

# %%
# Let's prepare for it.

transactions = []
toAdx = ''
fromAdx = ''

## Go through all elements containing an address or a transaction hash.
for i in range(len(elements)):
    adx = elements[i-1].text
    if i % 2 and not i % 3 == 0:
        fromAdx = adx
    if i % 3 == 0:
        toAdx = adx
        transactions.append((fromAdx, toAdx))

print(transactions)

print(len(transactions))
# Out:
# [('', 'Blur.io: Marketplace 3'), ('0x518f5390a4df8fb7c1f3654ef85c63c1f6f624214850b469b3fb99eccd52df80', '0x0a5eeb4067b75512e5e3e5b5ea3f4651851a6af65d37e86103b7e7d79207890f'), ('0xfbdbc1fe6827c0f647118a4a133be9e69860f0f8461db84c55495a4639d4d954', 'PancakeSwap: Cake Token'), ('0xf64e412683054129ed3f0bf95b6cfa858b33f507738
fdc7d69ac391322ed4ed740b2'), ('Uniswap: Universal Router', '0x5fa85c794a04515cae26f16136d048bc411eb89147365a5a78b3020d556ff316'), ('0xca14d0a7023311c52fef144e43c60aa8e2395bc00ab0f696e794f56f6fb85839', 'zkSync'), ('Metamask: Swap Router', '0xa1cc578c9488443cc9530786125bf374c4bc6d25ae2213bb8973aeaf4b4895b7'), ('Tether: USDT Stablecoin', 'junkyahd.eth')]
# 30

# %% [markdown]
# Let's build some simple statistics, counting the number of times an address receive/send a transaction.

# %%
from collections import defaultdict
sentCounts = defaultdict(int)
receivedCounts = defaultdict(int)

for i in range(len(elements)):
    adx = elements[i-1].text
    if i % 2 and not i % 3 == 0:
        sentCounts[adx] += 1
    if i % 3 == 0:
        receivedCounts[adx] += 1


print('Sent Counts')
print(sentCounts)
print('Received Counts')
print(receivedCounts)
# Out:
# Sent Counts
# defaultdict(<class 'int'>, {'0x518f5390a4df8fb7c1f3654ef85c63c1f6f624214850b469b3fb99eccd52df80': 1, '0xfbdbc1fe6827c0f647118a4a133be9e69860f0f8461db84c55495a4639d4d954': 1, '0xf64e412683054129ed3f0bf95b6cfa858b33f507738e83753166953f01a04974': 1, '0x7dc3ab645b936c4b2ee8794bc7c5738bae4be93277252620d8455f8fdaaa7b11': 1, '0xeeaa3b015ec136a045f8322ec7f33247ef8ad0d9a52a561a5d12fff43bb2e179': 1, 'Seaport 1.5': 1, 'Tether: USDT Stablecoin': 2, '0x0f517de93e7079f784519ce07e22d84d303848a4873bb2eebe5d9646f728314a': 1, '0x2d0e231ddea86451e3c1aa390a4d7d9c30acb71155ef9a4def99cf21fbc7ef57': 1, 'Wrapped Ether': 1, 'neutralimpakt.eth': 1, 'StarkNet: StarkGate ETH Bridge': 1, '0xa20d85385bb2965f294f05ea51edb4d5f88ffb0de70d56be119b136fc96defea': 1, '0x984cadff939bdebfdd5b0161e6bfabd0d5b85f762b5a53bb3ba856124abab23c': 1, '0x549f8c75ced1fa787dbf362fcd59b769905973ee71b0c8b6e0b419e7a8941bc8': 1, 'Linea: L1 Message Service': 1, '0x7bbee918b5772035ec9f3fba05aa6917f8e6337ac40ca13295dbf97b1d3d6c0b': 1, '0x6f0ba303a506d4787224badd3a1bcd76aaf1627a8d18bfdbdcbd91ca473502ae': 1, '0xaaaa7d5e32ee54df7bb4d8d142c8e652989c94ee3f48d414afa4f35d02a2942b': 1, 'Caacon: CC Token': 1, '0x96b48e3732810ca33865c1b5a8cd5d4c3b495100008e09f11ab3635be6747bac': 1, 'miarts.eth': 1, 'Uniswap: Universal Router': 2, 'DeFi Franc: MON Staking': 1, '0xcf89f59f4d174206164f2f0a8a464e5c4038749132ef1054d7cd8d5499e26567': 1, '0xca14d0a7023311c52fef144e43c60aa8e2395bc00ab0f696e794f56f6fb85839': 1, 'Metamask: Swap Router': 1})
# Received Counts
# defaultdict(<class 'int'>, {'Blur.io: Marketplace 3': 1, '0x0a5eeb4067b75512e5e3e5b5ea3f4651851a6af65d37e86103b7e7d79207890f': 1, 'PancakeSwap: Cake Token': 1, '0x199e4a0a1eedf9222272f1598e8766033a55d2e4857d66feb2d5cf2c8dc989fd': 1, 'Roobet: Hot Wallet': 1, 'Uniswap: Universal Router': 3, '0x21c39e919731280e63ae53d69343a0c6184f8128936d27d545b2075d1df28a3a': 1, '0xe07d6796392e504e280182b331ce4c76ec7a17dbe626f5dab9f80d9f8099ddb9': 1, 'Tether: USDT Stablecoin': 1, 'shahparism.eth': 1, '0x9c0eb8615538db2d86e1b8d6a934387dc68f415ba91e99f84d5c75d375b8a625': 1, '0x0131e4d74ad68f28499feb840516691d0d13e214a33a0a95244fb7542dfa9bb4': 1, '0xd4b4e8006a79c45821820e4b5d0ce45f2d395446f8f125d61ab7200d577166e0': 1, '0xc01c98a8b2e38c39b646757da9f2d90fbe7a749efb28312a0b640d98a56f37b3': 1, 'StarkNet: StarkGate ETH Bridge': 2, '0x62cfc89a73f2da1bdf0f40cdadc588140e3b09b6c906b98d1851e818dcf2c0b7': 1, '0xc5d3014fdefea0854c2415a9a4bccba0dd4bdde8080bb509f20b254ee4911c70': 1, '0x1f05ff58c3d4d02e69e961758547450a077c405a2dcde46c0aa5d02a2a65cafd': 1, 'Shiba Inu: ShibaSwap': 1, '0x67380b8bcf52f47797a72d4657102c4acbc2f3dff883c4514d067324fd64163b': 1, '0xe3828f4d205d17a1148fecfbddaeb9c46b8a521212cbc2a03a9e74bf7448aac0': 1, '0x55e7f2f0d960561fbcac5e8d9da311a3e466644961ad44b9e58b339db29c8d9c': 1, '0x265f0f3100fad7abe3c4bbcc859cdcc5e1ad92dfdc7d69ac391322ed4ed740b2': 1, '0x5fa85c794a04515cae26f16136d048bc411eb89147365a5a78b3020d556ff316': 1, 'zkSync': 1, '0xa1cc578c9488443cc9530786125bf374c4bc6d25ae2213bb8973aeaf4b4895b7': 1, 'junkyahd.eth': 1})

# %%
# Support functions.

from datetime import datetime

def print_time():
    now = datetime.now()
    # dd/mm/YY H:M:S
    dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
    print("time: ", dt_string)

def update_to_from(elements):
    for i in range(len(elements)):
        adx = elements[i-1].text
        if i % 2 and not i % 3 == 0:
            sentCounts[adx] += 1
        if i % 3 == 0:
            receivedCounts[adx] += 1

# %%
# Fetch multiple pages of transactions.

url = 'https://etherscan.io/txs?ps=100&p='

# Reset counts.
sentCounts = defaultdict(int)
receivedCounts = defaultdict(int)

for i in range(1,4):
    my_url = url + str(i)
    driver.get(my_url)
    elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')
    update_to_from(elements)
    print_time()
# Out:
# time:  19/09/2023 14:13:55
# time:  19/09/2023 14:13:56
# time:  19/09/2023 14:13:58

# %%
def printSorted(dic):
    sorted_dic = sorted(dic.items(), key=lambda x: x[1], reverse=True)
    for i in sorted_dic:
        print(i[0], i[1])

# %%
print(elements)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_580")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_581")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_582")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_583")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_584")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_585")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_586")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_587")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_588")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_589")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_590")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_591")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_592")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_593")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_594")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_595")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_596")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_597")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_598")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_599")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_600")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_601")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_602")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_603")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_604")>, <selenium.webdriver.remote.webelement.WebElement (session="91b640ac5981b96946575b06bc6fc695", element="D6A9D16D12DFCB52FD2A8B206249E746_element_605")>, <selenium.webdriver.remote.webelement.WebElemen ...

# %%
printSorted(sentCounts)
# Out:
# Tether: USDT Stablecoin 13
# Uniswap: Universal Router 8
# 0x: Exchange Proxy 3
# Wrapped Ether 2
# Binance 14 2
# Kraken 7 2
# Uniswap V2: Router 2 2
# Uniswap: Universal Router 2 2
# Orbiter Finance: Bridge 2 2
# MEV Bot: 0xA69...78C 2
# 0x4afd6562ac144c28b8054bfe1247e57fe86e4848211770d9953cc37291c7bd84 1
# 0x066789e55dceedad90bd8881a0ef0bb9beca1c04e81112a1ca2aba0aabbbd68a 1
# 0x43d26a4cba8e3441f322b957b86c745fb5a53ed12019ad95388c593207e0eca2 1
# FixedFloat 1
# 0xcbb9de6f3e90d078497dfcdef57bdf6a7d2628bffbd9121f5f3c3c2fa9b89493 1
# 0xde87a1cb7861dc3130ad1f238ad5aba3da077a58c2246f8989d0cac5fc95565e 1
# Seaport 1.5 1
# BigEyes: BIG Token 1
# 0xf5c4d81caf0eb1d4b4582ef6aee61d76e65ada7eee97fc9af76afcca42df3c23 1
# 0x62c95dadfde231447191dcdc6c878f7a3bc15e1bf7fccc3881812fadaff610d7 1
# 0x82eb8d8dd5e8fbc6e4ab92b0a5c00a39accf04f2b65a38e879bb2656bc5815bc 1
# Base: Base Bridge 1
# shaishai.eth 1
# Stake.com 1
# 0x63a789a202df0b1779ba066ea3f9067400a19bf27037cf50b313442e76ad05a2 1
# 0xf667b04c1c27de2e73d5fc810c30845cef65bbfc0ad891c7175c9a2a7ef2ac83 1
# 0x9d9e2ffd2b9c4eeb4caee1a8c12f0e013981ba3cb91605e2902fcdaae9dc01df 1
# 0x7a81d9d52a757939f7c27885aa880f3c35695d5b79061ebd659fae1bd4c5d2c5 1
# 112233112233.eth 1
# 0x5300d574104ed3e7c5f5af5cce9bb5b5e8398474f867c0518331f871490d9e36 1
# Maker: Dai Stablecoin 1
# 0x2097efe09df16ddbec1c74bdbb2161ffb5da123cafd96dfbbb37dd67aabc37cb 1
# 0x07c9281aa2d39153ada8e09405a01f86dabb873880ea5941960033f99634b2a0 1
# 0x0477a217584577f1b4e8d5386fccddf63bbd5588c5a112964d706f2d28876f57 1
# 0x41c8ecd64a0eba59b9087452a5fd28bf40f4c8bdbbee7a5385087f3bd733afa1 1
# 0xbf42f588c9cf2bbdad17ed5aadfc9ef33cb0b1fb7d0affb18ef2d48062fdbab3 1
# 0xf62fcbe230da7cc7e7ed0e4edc64b8fe8bcb5f052d2c009e88872be16024decc 1
# 0x6117f7866a4962ee315f9cb2ec4c20ead2b1f126c95d97da872401a1b144758e 1
# 0xacd7350ba99907e4d021967315adb117488f44612e00213a3e0aaa97e77723a3 1
# 0x79182bec2733643dc123e32036332c547d4e2b87fc287d6ad09755d5bc75aafa 1
# Crypto.com 2 1
# 0xa5f8ee94004747a150467db0c6c0ddee309743412752460114e39154df49b46d 1
# 0x06334211fafccf187fabe41764cc29414135743ca86d7fc1ab697145b5038234 1
# 0x: Exchange Proxy 1
# 0xfd526c40a4b7d683ca28b1dc806483519422bc2092f4f5a2ad2f6ec69f369e7e 1
# Zora: Bridge 1
# 0x5be94083c412f13136c49e1e7b46b3ede300d8df94b9fda24d7eba76be30bb1f 1
# 0x1046202c7940a50873e0bf5f4659dc582b27c98f557fc9842249b664bd20ecb9 1
# 0x707d0ec6c5b25517fd9743b473b28366e01a1e7b8beaef42b45a32401004028a 1

# %% [markdown]
# Let's gather more pages of transactions.
#
# We can also try out different methods.

# %%
def getTxs(n=3, reset=True, showCounts=True, method="requests"):
    # Access global variables from within a function's body.
    global sentCounts
    global receivedCounts

    url = 'https://etherscan.io/txs?ps=100&p='

    # Reset counts.
    if reset:
        print('Counts reseted')
        sentCounts = defaultdict(int)
        receivedCounts = defaultdict(int)

    for i in range(1,n+1):
        my_url = url + str(i)

        if method == "requests":
            html = requests.get(my_url, headers=hdr)
            soup = BeautifulSoup(html.content, 'html.parser')
            elements = soup.select(".hash-tag")
        elif method == "selenium":
            driver.get(my_url)
            elements = driver.find_elements(By.CLASS_NAME, 'hash-tag')
        elif method == "urllib":
            req = Request(url, headers = hdr)
            page = urlopen(req)
            soup = BeautifulSoup(page, 'html.parser')
            elements = soup.select(".hash-tag")

        update_to_from(elements) 
        print_time()
    
    if showCounts:
        printSorted(sentCounts)
        printSorted(receivedCounts)

# %%
getTxs(1, method = "selenium", showCounts = False)

# %%
getTxs(1, method = "requests", showCounts = False)

# %%
getTxs(1, method = "urllib", showCounts = False)

# %%
printSorted(sentCounts)

# %%
printSorted(receivedCounts)

# %%
import pandas as pd

# %%
# Sent.
items = sentCounts.items()
df_sent = pd.DataFrame.from_dict(items)
df_sent.columns = ["address", "sent"]
df_sent.sort_values(by="sent", ascending=False)

# %%
# Sent.
items = receivedCounts.items()
df_received = pd.DataFrame.from_dict(items)
df_received.columns = ["address", "received"]
df_received.sort_values(by="received", ascending=False)

# %%
df_txs = pd.merge(df_sent, df_received, on = "address", how = "outer")
df_txs = df_txs.fillna(0)
df_txs.sort_values(by="received", ascending=False)

# %%
df_txs.plot.scatter(x='sent',
                    y='received',
                    c='DarkBlue')

# %%
import random

def jitter(x):
    return x + random.uniform(0, .5) -.25

df_txs['sent_jit'] = df_txs['sent'].apply(lambda x: jitter(x))
df_txs['received_jit'] = df_txs['received'].apply(lambda x: jitter(x))

# %%
df_txs.plot.scatter(x='sent_jit',
                    y='received_jit',
                    c='DarkBlue')
